# %%
import pandas as pd

print(pd.__version__)

df = pd.read_csv(
    "../data/raw/complaints_synthetic.csv"
)

df.head()
# Out:
# 3.0.5
#   complaint_id                                     complaint_text    category  \
# 0        C0001  Water leakage near Sainthamaruthu 12 school fl...       Water
# 1        C0002  Water main valve leaking near Kalmunaikudi 06 ...       Water
# 2        C0003  Electric meter box left open near Kalmunaikudi 05  Electrical
# 3        C0004  Standing water in drain breeding mosquitoes ne...    Drainage
# 4        C0005  Water meter reading appears incorrect for Kalm...       Water
#
#   priority           location  ward_number        timestamp  \
# 0   Medium  Sainthamaruthu 12           20  7/26/2026 14:00
# 1     High    Kalmunaikudi 06           14  6/24/2026 11:00
# 2      Low    Kalmunaikudi 05           14  7/18/2026 05:00
# 3     High        Kalmunai 03           12   6/6/2026 21:00
# 4      Low    Kalmunaikudi 01           12  7/29/2026 13:00
#
#                                department       status citizen_language  \
# ...

# %%
print(df.shape)
# Out:
# (1000, 12)

# %%
print(df.columns.tolist())
# Out:
# ['complaint_id', 'complaint_text', 'category', 'priority', 'location', 'ward_number', 'timestamp', 'department', 'status', 'citizen_language', 'has_image', 'duplicate_flag']

# %%
df["category"].value_counts()
# Out:
# category
# Public        135
# Boat          134
# Waste         131
# Electrical    125
# Billing       125
# Water         124
# Road          115
# Drainage      111
# Name: count, dtype: int64

# %%
df["priority"].value_counts()
# Out:
# priority
# Medium    408
# Low       343
# High      249
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# complaint_id        0
# complaint_text      0
# category            0
# priority            0
# location            0
# ward_number         0
# timestamp           0
# department          0
# status              0
# citizen_language    0
# has_image           0
# duplicate_flag      0
# dtype: int64

# %%
df["category"].value_counts()
# Out:
# category
# Public        135
# Boat          134
# Waste         131
# Electrical    125
# Billing       125
# Water         124
# Road          115
# Drainage      111
# Name: count, dtype: int64
